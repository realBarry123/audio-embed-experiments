# %%
# !git clone https://github.com/realBarry123/audio-embed-experiments
# %cd audio-embed-experiments

# %%
# !/venv/main/bin/pip install -r requirements.txt
# !/venv/main/bin/pip install -e audembed

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !mkdir experiments/lens/results

# %%
# !git pull

# %%
# !/venv/main/bin/python experiments/lens/nodiffusers.py

# %%
# !/venv/main/bin/python experiments/lens/main.py "A man saying 'Hello world' in a Scottish accent"
